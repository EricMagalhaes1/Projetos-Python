# %% [markdown]
# <a href="https://colab.research.google.com/github/EricMagalhaes1/Python/blob/main/Python_para_Financas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importação de Bibliotecas

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf

# %% [markdown]
# #Base de dados com uma Ação

# %%
gol_df = yf.download("GOLL4.SA", start='2015-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gol_df
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2015-01-02  14.97  15.20  14.61  14.99      14.99    901900
# 2015-01-05  14.90  15.01  14.41  14.85      14.85   1272500
# 2015-01-06  14.75  15.21  14.65  15.21      15.21   2183500
# 2015-01-07  15.15  15.33  14.55  14.55      14.55   1846900
# 2015-01-08  14.41  14.65  14.20  14.27      14.27   1569500
# ...           ...    ...    ...    ...        ...       ...
# 2023-07-20  10.05  10.11   9.60   9.65       9.65  10835500
# 2023-07-21   9.64  10.47   9.62  10.38      10.38  13908400
# 2023-07-24  10.38  10.60  10.09  10.45      10.45  11682900
# 2023-07-25  10.69  10.95   9.98  10.13      10.13  14981300
# 2023-07-26  10.08  10.16   9.87   9.93       9.93   4007800
#
# [2130 rows x 6 columns]

# %%
gol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2129 entries, 2015-01-02 to 2023-07-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2129 non-null   float64
#  1   High       2129 non-null   float64
#  2   Low        2129 non-null   float64
#  3   Close      2129 non-null   float64
#  4   Adj Close  2129 non-null   float64
#  5   Volume     2129 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 116.4 KB

# %%
gol_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2129.000000  2129.000000  2129.000000  2129.000000  2129.000000
# mean     14.870263    15.239901    14.482109    14.833631    14.833631
# std       9.216963     9.385082     9.038501     9.208501     9.208501
# min       1.160000     1.180000     1.130000     1.160000     1.160000
# 25%       7.700000     7.880000     7.550000     7.670000     7.670000
# 50%      13.050000    13.390000    12.620000    12.940000    12.940000
# 75%      20.610001    21.190001    20.030001    20.570000    20.570000
# max      43.669998    44.619999    41.310001    43.790001    43.790001
#
#              Volume
# count  2.129000e+03
# mean   6.168652e+06
# std    5.580364e+06
# min    0.000000e+00
# 25%    2.255700e+06
# 50%    4.496700e+06
# 75%    8.423100e+06
# max    6.724200e+07

# %%
gol_df[gol_df['Close']>= 43.79]
# Out:
#              Open       High    Low      Close  Adj Close   Volume
# Date
# 2019-08-01  41.25  44.619999  41.25  43.790001  43.790001  6664200

# %%
gol_df[(gol_df['Close']>= 1.15) & (gol_df['Close']<= 1.16)]
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2016-01-22   1.2  1.26  1.14   1.16       1.16  3830600

# %%
gol_df.to_csv('gol.csv')

# %%
gol_df2 = pd.read_csv('/content/gol.csv')
gol_df2
# Out:
#             Date   Open   High    Low  Close  Adj Close    Volume
# 0     2015-01-02  14.97  15.20  14.61  14.99      14.99    901900
# 1     2015-01-05  14.90  15.01  14.41  14.85      14.85   1272500
# 2     2015-01-06  14.75  15.21  14.65  15.21      15.21   2183500
# 3     2015-01-07  15.15  15.33  14.55  14.55      14.55   1846900
# 4     2015-01-08  14.41  14.65  14.20  14.27      14.27   1569500
# ...          ...    ...    ...    ...    ...        ...       ...
# 2125  2023-07-20  10.05  10.11   9.60   9.65       9.65  10835500
# 2126  2023-07-21   9.64  10.47   9.62  10.38      10.38  13908400
# 2127  2023-07-24  10.38  10.60  10.09  10.45      10.45  11682900
# 2128  2023-07-25  10.69  10.95   9.98  10.13      10.13  14981300
# 2129  2023-07-26  10.08  10.16   9.87   9.93       9.93   4007800
#
# [2130 rows x 7 columns]

# %% [markdown]
# #Base de dados com mais ações

# %%
acoes = ['GOLL4.SA','CVCB3.SA','WEGE3.SA','MGLU3.SA', 'TOTS3.SA', 'BOVA11.SA']

# %%
acoes_df = pd.DataFrame()
for acao in acoes:
  acoes_df[acao] = yf.download(acao, start='2015-01-01')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
acoes_df
# Out:
#             GOLL4.SA  CVCB3.SA   WEGE3.SA  MGLU3.SA   TOTS3.SA   BOVA11.SA
# Date
# 2015-01-02     14.99     15.20   5.923076  0.232812  11.910702   47.259998
# 2015-01-05     14.85     15.00   5.963461  0.237187  11.544731   46.320000
# 2015-01-06     15.21     14.80   5.875000  0.234062  10.822770   46.580002
# 2015-01-07     14.55     14.67   5.807692  0.241875  10.746248   48.150002
# 2015-01-08     14.27     14.15   5.905769  0.240000  10.995774   48.509998
# ...              ...       ...        ...       ...        ...         ...
# 2023-07-20      9.65      3.00  38.160000  2.900000  28.530001  114.339996
# 2023-07-21     10.38      3.11  38.889999  3.020000  29.270000  116.400002
# 2023-07-24     10.45      3.08  41.540001  3.010000  29.530001  117.570000
# 2023-07-25     10.13      3.08  40.500000  3.070000  29.450001         NaN
# 2023-07-26     10.02      3.05  40.689999  3.070000  29.450001  117.769997
#
# [2130 rows x 6 columns]

# %%
acoes_df = acoes_df.rename(columns={'GOLL4.SA': 'GOL', 'CVCB3.SA': "CVC", 'WEGE3.SA': 'WEGE',
                                    'MGLU3.SA': 'MGLU','TOTS3.SA': 'TOTS', 'BOVA11.SA': 'BOVA'})

# %%
acoes_df.head()
# Out:
#               GOL    CVC      WEGE      MGLU       TOTS       BOVA
# Date
# 2015-01-02  14.99  15.20  5.923076  0.232812  11.910702  47.259998
# 2015-01-05  14.85  15.00  5.963461  0.237187  11.544731  46.320000
# 2015-01-06  15.21  14.80  5.875000  0.234062  10.822770  46.580002
# 2015-01-07  14.55  14.67  5.807692  0.241875  10.746248  48.150002
# 2015-01-08  14.27  14.15  5.905769  0.240000  10.995774  48.509998

# %%
acoes_df.isnull().sum()
# Out:
# GOL      0
# CVC      0
# WEGE     0
# MGLU     0
# TOTS     0
# BOVA    28
# dtype: int64

# %%
acoes_df.shape
# Out:
# (2130, 6)

# %%
acoes_df.dropna(inplace=True)

# %%
acoes_df.shape
# Out:
# (2102, 6)

# %%
acoes_df.isnull().sum()
# Out:
# GOL     0
# CVC     0
# WEGE    0
# MGLU    0
# TOTS    0
# BOVA    0
# dtype: int64

# %%
acoes_df.to_csv('acoes.csv')

# %%
acoes_df = pd.read_csv('acoes.csv')
acoes_df
# Out:
#             Date  GOLL4.SA  CVCB3.SA   WEGE3.SA  MGLU3.SA   TOTS3.SA  \
# 0     2015-01-02     14.99     15.20   5.923076  0.232812  11.910702
# 1     2015-01-05     14.85     15.00   5.963461  0.237187  11.544731
# 2     2015-01-06     15.21     14.80   5.875000  0.234062  10.822770
# 3     2015-01-07     14.55     14.67   5.807692  0.241875  10.746248
# 4     2015-01-08     14.27     14.15   5.905769  0.240000  10.995774
# ...          ...       ...       ...        ...       ...        ...
# 2098  2023-07-20      9.65      3.00  38.160000  2.900000  28.530001
# 2099  2023-07-21     10.38      3.11  38.889999  3.020000  29.270000
# 2100  2023-07-24     10.45      3.08  41.540001  3.010000  29.530001
# 2101  2023-07-25     10.13      3.08  40.500000  3.070000  29.450001
# 2102  2023-07-26     10.29      3.09  40.480000  3.090000  29.730000
#
#        BOVA11.SA
# 0      47.259998
# 1      46.320000
# 2      46.580002
# 3      48.150002
# 4      48.509998
# ...          ...
# 2098  114.339996
# 2099  116.400002
# 2100  117.570000
# 2101  117.980003
# 2102  118.739998
#
# [2103 rows x 7 columns]

# %%
acoes_df.columns[1:]
# Out:
# Index(['GOLL4.SA', 'CVCB3.SA', 'WEGE3.SA', 'MGLU3.SA', 'TOTS3.SA',
#        'BOVA11.SA'],
#       dtype='object')

# %%
acoes_df.describe()
# Out:
#                GOL          CVC         WEGE         MGLU         TOTS  \
# count  2102.000000  2102.000000  2102.000000  2102.000000  2102.000000
# mean     14.757231    26.100830    18.504243     6.581271    18.690019
# std       9.204182    16.667962    13.252337     7.458880     9.483429
# min       1.160000     2.550000     4.942307     0.030585     7.156402
# 25%       7.660000    14.000000     6.865384     0.603515    10.160694
# 50%      12.795000    20.521320     9.651923     3.795624    13.640406
# 75%      20.507500    41.195001    33.122500     9.198125    28.030001
# max      43.790001    64.800003    46.105000    27.450001    40.599998
#
#               BOVA
# count  2102.000000
# mean     83.458563
# std      24.081393
# min      36.450001
# 25%      61.230000
# 50%      88.830002
# 75%     104.694998
# max     125.750000

# %% [markdown]
# #Visualização

# %%
sns.histplot(acoes_df['GOL']);

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.histplot(acoes_df[acoes_df.columns[i]], kde=True)
  plt.title(acoes_df.columns[i])

# %%
acoes_df['GOL'].describe()
# Out:
# count    2102.000000
# mean       14.757231
# std         9.204182
# min         1.160000
# 25%         7.660000
# 50%        12.795000
# 75%        20.507500
# max        43.790001
# Name: GOL, dtype: float64

# %%
sns.boxplot(x = acoes_df['GOL']);

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.boxplot(x = acoes_df[acoes_df.columns[i]])
  plt.title(acoes_df.columns[i])

# %%
acoes_df.plot(x = 'Date', figsize = (15,7), title = 'Histórico do preço das ações');
